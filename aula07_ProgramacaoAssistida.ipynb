# %% [markdown]
# <a href="https://colab.research.google.com/github/reiflexo/engenharia_de_prompt_aplicacoes_ai/blob/main/aula07_ProgramacaoAssistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula: Programação Assitida
# Nome: Francisco Rian Alves (Turma Sextou)

# %%
# Define uma lista de números inteiros
numeros = [1,2,3]
# Calcula a soma de todos os elementos na lista 'numeros'
soma = sum(numeros)
# Imprime a lista original
print(f"A lista é: {numeros}")
# Imprime a soma dos elementos da lista
print(f"A soma dos elementos é: {soma}")
# Out:
# A lista é: [1, 2, 3]
# A soma dos elementos é: 6

# %% [markdown]
# Eh primo

# %% [markdown]
# Inversão String

# %%
def iverte_texto(texto):
  invertido = ' '
  for letra in texto:
    invertido = letra + invertido
  return

# %%
A = ['r', 'i', 'a', 'n']
print(A[::-1])
# Out:
# ['n', 'a', 'i', 'r']

# %% [markdown]
# Mini projeto

# %%
a = input('digite um valo: ')
b = input('digite um sinal: ')
c = input('digite um valo: ')
soma = a b c
# Out:
#   File "/tmp/ipykernel_6739/565175614.py", line 4
#     soma = a b c
#              ^
# SyntaxError: invalid syntax
